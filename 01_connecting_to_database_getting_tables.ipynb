# %%
import psycopg2
import os
import pandas as pd
from dotenv import load_dotenv

load_dotenv()

conn = psycopg2.connect(
    host=os.getenv("DB_HOST"),
    database=os.getenv("DB_NAME"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASSWORD"),
    port=os.getenv("DB_PORT")
)

print("Connection successflu")


currencyexchange = pd.read_sql("SELECT * FROM currencyexchange", conn)
customer = pd.read_sql("SELECT * FROM customer", conn)
date = pd.read_sql("SELECT * FROM date", conn)
product = pd.read_sql("SELECT * FROM product", conn)
sales = pd.read_sql("SELECT * FROM sales", conn)
store = pd.read_sql("SELECT * FROM store", conn)
# Out:
# C:\Users\amyre\AppData\Local\Temp\ipykernel_54660\375540979.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   currencyexchange = pd.read_sql("SELECT * FROM currencyexchange", conn)
# C:\Users\amyre\AppData\Local\Temp\ipykernel_54660\375540979.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customer = pd.read_sql("SELECT * FROM customer", conn)
# C:\Users\amyre\AppData\Local\Temp\ipykernel_54660\375540979.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   date = pd.read_sql("SELECT * FROM date", conn)
# C:\Users\amyre\AppData\Local\Temp\ipykernel_54660\375540979.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product = pd.read_sql("SELECT * FROM product", conn)
# C:\Users\amyre\AppData\Local\Temp\ipykernel_54660\375540979.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sales = pd.read_sql("SELECT * FROM sales", conn)
# C:\Users\amyre\AppData\Local\Temp\ipykernel_54660\375540979.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   store = pd.read_sql("SELECT * FROM store", conn)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199873 entries, 0 to 199872
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   orderkey      199873 non-null  int64
#  1   linenumber    199873 non-null  int64
#  2   orderdate     199873 non-null  object
#  3   deliverydate  199873 non-null  object
#  4   customerkey   199873 non-null  int64
#  5   storekey      199873 non-null  int64
#  6   productkey    199873 non-null  int64
#  7   quantity      199873 non-null  int64
#  8   unitprice     199873 non-null  float64
#  9   netprice      199873 non-null  float64
#  10  unitcost      199873 non-null  float64
#  11  currencycode  199873 non-null  object
#  12  exchangerate  199873 non-null  float64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 19.8+ MB
